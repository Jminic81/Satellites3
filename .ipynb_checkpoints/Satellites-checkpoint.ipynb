# %%
#Analysis and Visualization of Active Satellites in Orbit around Earth; Jonathan Bouchet's Kaggle submission.  
#The Readme contains original background and discussion of the data analysis in this Jupyter Notebook. 

#Import all libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings  #Chose to ignore the warnings that are printed by the Seaborn library
warnings.filterwarnings("ignore")
sns.set(style="white", color_codes=True)

# %%
#Read the first .csv file into data frame "sat".
sat=pd.read_csv("database.csv")

# %%
#Verify all rows and columns are present.
sat.shape
# Out:
# (1420, 26)

# %%
#View the first five rows.
sat.head()
# Out:
#   Official Name of Satellite Country/Organization of UN Registry  \
# 0                   AAUSat-4                                  NR
# 1                      ABS-2                                  NR
# 2                     ABS-2A                                  NR
# 3                      ABS-3                         Philippines
# 4                     ABS-3A                                  NR
#
#                   Operator/Owner Country of Operator/Owner       Users  \
# 0          University of Aalborg                   Denmark       Civil
# 1  Asia Broadcast Satellite Ltd.             Multinational  Commercial
# 2  Asia Broadcast Satellite Ltd.             Multinational  Commercial
# 3  Asia Broadcast Satellite Ltd.             Multinational  Commercial
# 4  Asia Broadcast Satellite Ltd.             Multinational  Commercial
#
#              Purpose                       Detailed Purpose Class of Orbit  \
# ...

# %%
#View the last five rows.
sat.tail()
# Out:
#      Official Name of Satellite Country/Organization of UN Registry  \
# 1415                Zhongxing 9                               China
# 1416                   Zijing 1                                  NR
# 1417               Ziyuan 1-02C                               China
# 1418                   Ziyuan 3                               China
# 1419                  Ziyan 3-2                                  NR
#
#                                          Operator/Owner  \
# 1415  China Satellite Communication Corp. (China Sat...
# 1416                                Tsinghua University
# 1417  China Centre for Resources Satellite Data and ...
# 1418  China Centre for Resources Satellite Data and ...
# 1419  China Centre for Resources Satellite Data and ...
#
#      Country of Operator/Owner       Users                 Purpose  \
# 1415                     China  Government          Communications
# 1416                     China       Civil  Technology Development
# ...

# %%
#View column names.
sat.columns
# Out:
# Index(['Official Name of Satellite', 'Country/Organization of UN Registry',
#        'Operator/Owner', 'Country of Operator/Owner', 'Users', 'Purpose',
#        'Detailed Purpose', 'Class of Orbit', 'Type of Orbit',
#        'Longitude of Geosynchronous Orbit (Degrees)', 'Perigee (Kilometers)',
#        'Apogee (Kilometers)', 'Eccentricity', 'Inclination (Degrees)',
#        'Period (Minutes)', 'Launch Mass (Kilograms)', 'Dry Mass (Kilograms)',
#        'Power (Watts)', 'Date of Launch', 'Expected Lifetime (Years)',
#        'Contractor', 'Country of Contractor', 'Launch Site', 'Launch Vehicle',
#        'COSPAR Number', 'NORAD Number'],
#       dtype='object')

# %%
#Flag cells that are blank.
sat.isnull()
# Out:
#       Official Name of Satellite  Country/Organization of UN Registry  \
# 0                          False                                False
# 1                          False                                False
# 2                          False                                False
# 3                          False                                False
# 4                          False                                False
# 5                          False                                False
# 6                          False                                False
# 7                          False                                False
# 8                          False                                False
# 9                          False                                False
# 10                         False                                False
# 11                         False                                False
# ...

# %%
#Summarize the location and number of cells that are blank.  See Readme for discussion of cells that are not blank but do not
#contain valid data.
sat.isnull().sum()
# Out:
# Official Name of Satellite                        0
# Country/Organization of UN Registry               0
# Operator/Owner                                    1
# Country of Operator/Owner                         0
# Users                                             1
# Purpose                                           1
# Detailed Purpose                               1051
# Class of Orbit                                    1
# Type of Orbit                                   521
# Longitude of Geosynchronous Orbit (Degrees)      18
# Perigee (Kilometers)                              1
# Apogee (Kilometers)                               1
# Eccentricity                                      1
# Inclination (Degrees)                             1
# Period (Minutes)                                  3
# Launch Mass (Kilograms)                         103
# Dry Mass (Kilograms)                            947
# Power (Watts)                                   771
# ...

# %%
#Summarize Class of Orbit in descending order.
sat["Class of Orbit"].value_counts()
# Out:
# LEO           779
# GEO           506
# MEO            96
# Elliptical     37
# LEO             1
# Name: Class of Orbit, dtype: int64

# %%
#Use bar chart (pareto chart) to show Class of Orbit by count in descending order.
Class_of_Orbit = sat['Class of Orbit'].value_counts()
Class_of_Orbit.head(4).plot(kind='bar')
plt.title('Satellite Class of Orbit')
plt.xlabel('Orbit Class')
plt.ylabel('Number of Satellites')
plt.show()

# %%
#Summarize Dry Mass (Kilograms) in descending order.
sat["Dry Mass (Kilograms)"].value_counts()
# Out:
# 556            70
# 22             25
# 350            22
# 980            17
# 12             12
# 1600           12
# 1900           10
# 2000            8
# 1700            7
# 2500            7
# 3450            7
# 1545            6
# 884             6
# 150             5
# 598             5
# 620             4
# 77              4
# 1500            4
# 478             4
# 2200            4
# 860             4
# 2146            4
# 1100            3
# 2100            3
# 1570            3
# 1450            3
# 10000           3
# 3200            3
# 1972            3
# 1800            3
#                ..
# 2304            1
# 3500            1
# 2240            1
# 3655            1
# 975             1
# 10              1
# 3360            1
# 3812            1
# 1730            1
# 912             1
# 726             1
# 2778            1
# 53              1
# 2275            1
# 2060            1
# 1380            1
# 2310            1
# 1669            1
# 2393            1
# ...

# %%
#Summarize Country of Operator/Owner in descending order.
sat["Country of Operator/Owner"].value_counts()
# Out:
# USA                               561
# China                             180
# Russia                            136
# Multinational                      67
# Japan                              57
# United Kingdom                     41
# India                              38
# ESA                                33
# Canada                             28
# Germany                            24
# Luxembourg                         18
# Spain                              15
# Israel                             12
# Saudi Arabia                       11
# Argentina                          11
# Netherlands                        10
# France                              9
# Brazil                              9
# Singapore                           9
# South Korea                         9
# Indonesia                           8
# Italy                               7
# Australia                           7
# United Arab Emirates                6
# Norway                              6
# ...

# %%
#Use bar chart (pareto chart) to show Country of Operator/Owner by count in descending order.
Country_Operator_Owner = sat["Country of Operator/Owner"].value_counts()
Country_Operator_Owner.head(20).plot(kind='bar')
plt.title('Satellite Ownership by Count')
plt.xlabel('Country of Operator/Owner')
plt.ylabel('Number of Satellites')
plt.show()

# %%
#Summarize Purpose in descending order.
sat["Purpose"].value_counts()
# Out:
# Communications                                    699
# Earth Observation                                 355
# Technology Development                            154
# Navigation/Global Positioning                      97
# Space Science                                      62
# Earth Science                                       9
# Navigation/Regional Positioning                     8
# Communications/Technology Development               8
# Technology Demonstration                            6
# Space Observation                                   5
# Earth Observation/Technology Development            5
# Communications/Maritime Tracking                    5
# Earth Observation/Communications                    2
# Communications/Navigation                           1
# Earth/Space Science                                 1
# Earth Observation/Research                          1
# Earth Observation/Communications/Space Science      1
# Name: Purpose, dtype: int64

# %%
#Use pie chart to summarize purpose - best to only use 6 "slices" so bottom 12 items were combined into "Other" 
labels = ['Communications', 'Earth Observation', 'Technology Development', 'Navigation/GPS', 'Earth/Space Science', 'Other']
sizes = [699,355,154,97,71,43]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels = labels, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Satellite Purpose')
plt.show()

# %%
#Summarize Expected Lifetime (Years) in descending order.
sat["Expected Lifetime (Years)"].value_counts()
# Out:
# 15           279
# 5            148
# 8             88
# 10            84
# 12            83
# 3             60
# 7             55
# 2             31
# 1 yr.         19
# 4             18
# 13            18
# 7-May         13
# 14             7
# 11             6
# 18             5
# 6              5
# 16             5
# 12-Oct         5
# 5-Mar          4
# 3-Feb          4
# 8-May          4
# 10-Jul         3
# 9-Jul          3
# 15-18          2
# 0.25           2
# 9              2
# 4-Feb          2
# 0.5            2
# 7.25           2
# 12.6           2
# 13 trs,        1
# 1.5            1
# 10-Feb         1
# 11.5           1
# .25-1 yr.      1
# 17             1
# 14yrs.         1
# 15-Oct         1
# 12 hrs.        1
# 14-Oct         1
# 20             1
# 12-Sep         1
# 2.5            1
# 30             1
# 14.5           1
# Name: Expected Lifetime (Years), dtype: int64
